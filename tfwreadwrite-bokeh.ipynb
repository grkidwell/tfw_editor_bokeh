# %%
import sys
import tfwlib as tfw
import numpy as np
#import matplotlib.pyplot as plt
from bokeh.io import output_notebook, show, curdoc
from bokeh.plotting import figure #, show
from bokeh.layouts import widgetbox, gridplot
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import DataTable, TableColumn, IntEditor
#from bokeh.plotting import curdoc
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9443">Loading BokehJS ...</span>
#     </div>

# %%
def on_change_data_source(attr, old, new):
    print('-- OLD DATA: {}'.format(old))
    print('-- NEW DATA: {}'.format(new))
    print('-- SOURCE DATA: {}'.format(source.data))

    # to check changes in the 'y' column:
    indices = list(range(len(old['y'])))
    changes = [(i,j,k) for i,j,k in zip(indices, old['y'], new['y']) if j != k]
    if changes != []:
        for t in changes:  # t = (index, old_val, new_val)
            patch = {
                'y' : [(t[0], int(t[2])), ]   # the new value is received as a string
            }
            source.patch(patch)   # this will call to this callback again, ugly
                                  # so you will need to update the values on another source variable
        print('-- SOURCE DATA AFTER PATCH: {}'.format(source.data))

# %%
data=tfw.read_tfw('TestWaveform2.TFW')
x=np.arange(data.size)
fig=figure(plot_height=400, plot_width=400)

# %%
'''
Testwaveform_tri_double_high.TFW
data[1800:1900]= 0
data[1840:1850]=8191     
data[1990:2000]=16382
data[2005:2010]=0
data[2015:2020]=16382
'''

'''
Testwaveform_tri_double_high2.TFW
data[1800:1900]= 0
data[1840:1860]=8191    
data[1990:2000]=16382
data[2005:2010]=0
data[2015:2020]=16382
'''
'''
2xtri_double_high.TFW

'''
data[1800:1900]= 0
data[1850:1870]=8191    
data[1990:2000]=16382
data[2005:2010]=0
data[2015:2020]=16382
'''
3xtri_double_high.TFW
data[1800:1900]= 0
data[1840:1870]=8191    
data[1990:2000]=16382
data[2005:2010]=0
data[2015:2020]=16382
'''
'''
4xtri_double_high.TFW
data[1800:1900]= 0
data[1830:1870]=8191    
data[1990:2000]=16382
data[2005:2010]=0
data[2015:2020]=16382
'''
'''
4xtri_high_2xlow_high.TFW
data[1800:1900]= 0
data[1830:1870]=8191    
data[1990:2000]=16382
data[2005:2020]=0
data[2020:2030]=16382
'''
'''
4xtri_high_2xlow_2xhigh.TFW
data[1800:1900]= 0
data[1830:1870]=8191    
data[1990:2000]=16382
data[2005:2020]=0
data[2020:2040]=16382
'''
'''
4xtri_2xhigh_2xlow_2xhigh.TFW
data[1800:1900]= 0
data[1830:1870]=8191    
data[1980:2000]=16382
data[2005:2020]=0
data[2020:2040]=16382
'''
'''
4xtri_2xhigh_4xlow_2xhigh.TFW
data[1800:1900]= 0
data[1830:1870]=8191    
data[1980:2000]=16382
data[2000:2040]=0
data[2040:2060]=16382
'''
# Out:
# '\n4xtri_2xhigh_4xlow_2xhigh.TFW\ndata[1800:1900]= 0\ndata[1830:1870]=8191    \ndata[1980:2000]=16382\ndata[2000:2040]=0\ndata[2040:2060]=16382\n'

# %%
datapoints = dict(
        timeindex=x,
        amplitude=data,
    )
source = ColumnDataSource(datapoints)

#source.on_change('data', on_change_data_source)
columns = [
        TableColumn(field="timeindex", title="Time Index", editor=IntEditor()),
        TableColumn(field="amplitude", title="Waveform Amplitude", editor=IntEditor()),
    ]
data_table=DataTable(source=source,columns=columns,width=300, height=280, editable=True, selectable=True, sortable=True)
fig.line(x='timeindex',y='amplitude', source=source,color='blue')
#curdoc().add_root(data_table)
show(data_table), show(fig)
# Out:
#   <div class="bk-root" id="8ce02c80-7c87-4bab-b37e-7f6d6ec2cdc9" data-root-id="8975"></div>
#   <div class="bk-root" id="bb5c7d3c-9884-4e16-b6a1-13f09d58bfba" data-root-id="8934"></div>
# (None, None)

# %%
tfw.write_tfw('2xtri_high_low_high.TFW', data)

# %%
2.5e-6/2500
# Out:
# 1e-09
